# %%
import yfinance as yf

# %%
sp500=yf.Ticker("^GSPC")

# %%
sp500=sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-04-10 00:00:00-04:00  5353.149902  5353.149902  5115.270020  5268.049805
# 2025-04-11 00:00:00-04:00  5255.560059  5381.459961  5220.770020  5363.359863
# 2025-04-14 00:00:00-04:00  5441.959961  5459.459961  5358.020020  5405.970215
# 2025-04-15 00:00:00-04:00  5411.990234  5450.410156  5386.439941  5396.629883
# 2025-04-16 00:00:00-04:00  5335.750000  5367.240234  5220.790039  5275.700195
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-04-03 00:00:00-04:00', '2025-04-04 00:00:00-04:00',
#                '2025-04-07 00:00:00-04:00', '2025-04-08 00:00:00-04:00',
#                '2025-04-09 00:00:00-04:00', '2025-04-10 00:00:00-04:00',
#                '2025-04-11 00:00:00-04:00', '2025-04-14 00:00:00-04:00',
#                '2025-04-15 00:00:00-04:00', '2025-04-16 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24439, freq=None)

# %%
sp500.plot.line(y='Close',use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500['Dividends']
del sp500['Stock Splits']
sp500.head()
# Out:
#                                 Open       High        Low      Close  Volume
# Date
# 1927-12-30 00:00:00-05:00  17.660000  17.660000  17.660000  17.660000       0
# 1928-01-03 00:00:00-05:00  17.760000  17.760000  17.760000  17.760000       0
# 1928-01-04 00:00:00-05:00  17.719999  17.719999  17.719999  17.719999       0
# 1928-01-05 00:00:00-05:00  17.549999  17.549999  17.549999  17.549999       0
# 1928-01-06 00:00:00-05:00  17.660000  17.660000  17.660000  17.660000       0

# %%
sp500["Tomorrow"]=sp500['Close'].shift(-1)
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-04-10 00:00:00-04:00  5353.149902  5353.149902  5115.270020  5268.049805
# 2025-04-11 00:00:00-04:00  5255.560059  5381.459961  5220.770020  5363.359863
# 2025-04-14 00:00:00-04:00  5441.959961  5459.459961  5358.020020  5405.970215
# 2025-04-15 00:00:00-04:00  5411.990234  5450.410156  5386.439941  5396.629883
# 2025-04-16 00:00:00-04:00  5335.750000  5367.240234  5220.790039  5275.700195
#
# ...

# %%
sp500['Target']=(sp500['Tomorrow']>sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-04-10 00:00:00-04:00  5353.149902  5353.149902  5115.270020  5268.049805
# 2025-04-11 00:00:00-04:00  5255.560059  5381.459961  5220.770020  5363.359863
# 2025-04-14 00:00:00-04:00  5441.959961  5459.459961  5358.020020  5405.970215
# 2025-04-15 00:00:00-04:00  5411.990234  5450.410156  5386.439941  5396.629883
# 2025-04-16 00:00:00-04:00  5335.750000  5367.240234  5220.790039  5275.700195
#
# ...

# %%
sp500=sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-04-10 00:00:00-04:00  5353.149902  5353.149902  5115.270020  5268.049805
# 2025-04-11 00:00:00-04:00  5255.560059  5381.459961  5220.770020  5363.359863
# 2025-04-14 00:00:00-04:00  5441.959961  5459.459961  5358.020020  5405.970215
# 2025-04-15 00:00:00-04:00  5411.990234  5450.410156  5386.439941  5396.629883
# 2025-04-16 00:00:00-04:00  5335.750000  5367.240234  5220.790039  5275.700195
#
# ...

# %%
#training ml model
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100,min_samples_split=100,random_state=1)
train=sp500.iloc[:-100]
test=sp500.iloc[-100:]
predictors=["Close","Volume","Open","High","Low"]
model.fit(train[predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score
preds=model.predict(test[predictors])

# %%
import pandas as pd

preds=pd.Series(preds,index=test.index)
preds
# Out:
# Date
# 2024-11-20 00:00:00-05:00    1
# 2024-11-21 00:00:00-05:00    1
# 2024-11-22 00:00:00-05:00    1
# 2024-11-25 00:00:00-05:00    1
# 2024-11-26 00:00:00-05:00    0
#                             ..
# 2025-04-10 00:00:00-04:00    1
# 2025-04-11 00:00:00-04:00    1
# 2025-04-14 00:00:00-04:00    1
# 2025-04-15 00:00:00-04:00    1
# 2025-04-16 00:00:00-04:00    1
# Length: 100, dtype: int64

# %%
precision_score(test['Target'],preds)
# Out:
# 0.5277777777777778

# %%
combined=pd.concat([test["Target"],preds],axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#backtracking system
def predict(train,test,predictors,model):
  model.fit(train[predictors],train["Target"])
  preds=model.predict(test[predictors])
  preds=pd.Series(preds,index=test.index,name="Predictions")
  combined=pd.concat([test["Target"],preds],axis=1)
  return combined

# %%
def backtest(data,model,predictors,start=2500,step=250):
  all_predictions=[]

  for i in range(start,data.shape[0],step):
    train=data.iloc[0:i].copy()
    test=data.iloc[i:(i+step)].copy()
    predictions=predict(train,test,predictors,model)
    all_predictions.append(predictions)
  return pd.concat(all_predictions)

# %%
predictions=backtest(sp500,model,predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 0    3736
# 1    2653
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5284583490388239

# %%
predictions["Target"].value_counts()/predictions.shape[0]
# Out:
# Target
# 1    0.535608
# 0    0.464392
# Name: count, dtype: float64

# %%
#add more predictors
horizons=[2,5,60,250,1000]
new_predictors=[]
for horizon in horizons:
  rolling_averages=sp500.rolling(horizon).mean()
  ratio_column=f"Close_Ratio_{horizon}"
  sp500[ratio_column]=sp500["Close"]/rolling_averages["Close"]
  trend_column=f"Trend_{horizon}"
  sp500[trend_column]=sp500.shift(1).rolling(horizon).sum()["Target"]
  new_predictors+=[ratio_column,trend_column]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-04-10 00:00:00-04:00  5353.149902  5353.149902  5115.270020  5268.049805
# 2025-04-11 00:00:00-04:00  5255.560059  5381.459961  5220.770020  5363.359863
# 2025-04-14 00:00:00-04:00  5441.959961  5459.459961  5358.020020  5405.970215
# 2025-04-15 00:00:00-04:00  5411.990234  5450.410156  5386.439941  5396.629883
# 2025-04-16 00:00:00-04:00  5335.750000  5367.240234  5220.790039  5275.700195
#
# ...

# %%
sp500=sp500.dropna()
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2025-04-09 00:00:00-04:00  4965.279785  5481.339844  4948.430176  5456.899902
# 2025-04-10 00:00:00-04:00  5353.149902  5353.149902  5115.270020  5268.049805
# 2025-04-11 00:00:00-04:00  5255.560059  5381.459961  5220.770020  5363.359863
# 2025-04-14 00:00:00-04:00  5441.959961  5459.459961  5358.020020  5405.970215
# 2025-04-15 00:00:00-04:00  5411.990234  5450.410156  5386.439941  5396.629883
#
# ...

# %%
#model improvement
model=RandomForestClassifier(n_estimators=200,min_samples_split=50,random_state=1)

# %%
def predict(train,test,predictors,model):
  model.fit(train[predictors],train["Target"])
  preds=model.predict_proba(test[predictors])[:,1]
  preds[preds>=.6]=1
  preds[preds<=.6]=0
  preds=pd.Series(preds,index=test.index,name="Predictions")
  combined=pd.concat([test["Target"],preds],axis=1)
  return combined

# %%
predictions=backtest(sp500,model,new_predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 0.0    4519
# 1.0     869
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.570771001150748

# %%
#applying weights
# Weighted predict function
def predict(train, test, predictors, model):
    # Create weights: older samples get lower, recent samples get higher weight
    weights = np.linspace(0.1, 1.0, len(train))

    # Fit the model with weights
    model.fit(train[predictors], train["Target"], sample_weight=weights)

    # Predict probabilities
    preds = model.predict_proba(test[predictors])[:,1]

    # Apply decision threshold
    preds[preds >= 0.6] = 1
    preds[preds < 0.6] = 0

    # Format predictions
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)

    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i + step)].copy()

        print(f"Training on rows 0 to {i}")
        print(f"Testing on rows {i} to {i + step}")
        print(f"Train shape: {train.shape}, Test shape: {test.shape}")

        predictions = predict(train, test, predictors, model)

        if predictions is not None and not predictions.empty:
            all_predictions.append(predictions)
        else:
            print(f"No predictions returned for range {i}-{i + step}")

    if all_predictions:
        return pd.concat(all_predictions)
    else:
        raise ValueError("No valid predictions were generated during backtesting.")

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
# Run your backtest
predictions = backtest(sp500, model, new_predictors)
# Out:
# Training on rows 0 to 2500
# Testing on rows 2500 to 2750
# Train shape: (2500, 17), Test shape: (250, 17)
# Training on rows 0 to 2750
# Testing on rows 2750 to 3000
# Train shape: (2750, 17), Test shape: (250, 17)
# Training on rows 0 to 3000
# Testing on rows 3000 to 3250
# Train shape: (3000, 17), Test shape: (250, 17)
# Training on rows 0 to 3250
# Testing on rows 3250 to 3500
# Train shape: (3250, 17), Test shape: (250, 17)
# Training on rows 0 to 3500
# Testing on rows 3500 to 3750
# Train shape: (3500, 17), Test shape: (250, 17)
# Training on rows 0 to 3750
# Testing on rows 3750 to 4000
# Train shape: (3750, 17), Test shape: (250, 17)
# Training on rows 0 to 4000
# Testing on rows 4000 to 4250
# Train shape: (4000, 17), Test shape: (250, 17)
# Training on rows 0 to 4250
# Testing on rows 4250 to 4500
# Train shape: (4250, 17), Test shape: (250, 17)
# Training on rows 0 to 4500
# Testing on rows 4500 to 4750
# Train shape: (4500, 17), Test shape: (250, 17)
# ...

# %%
print("Prediction distribution:")
print(predictions['Predictions'].value_counts())

print("Precision Score:")
print(precision_score(predictions["Target"], predictions["Predictions"]))
# Out:
# Prediction distribution:
# Predictions
# 0.0    4554
# 1.0     834
# Name: count, dtype: int64
# Precision Score:
# 0.5695443645083933

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score

# Weighted predict function
def predict(train, test, predictors, model):
    weights = np.linspace(0.1, 1.0, len(train))
    model.fit(train[predictors], train["Target"], sample_weight=weights)
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= 0.6] = 1
    preds[preds < 0.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# Backtesting loop
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i + step)].copy()
        print(f"Training on rows 0 to {i}")
        print(f"Testing on rows {i} to {i + step}")
        print(f"Train shape: {train.shape}, Test shape: {test.shape}")
        predictions = predict(train, test, predictors, model)
        if predictions is not None and not predictions.empty:
            all_predictions.append(predictions)
        else:
            print(f"No predictions returned for range {i}-{i + step}")
    if all_predictions:
        return pd.concat(all_predictions)
    else:
        raise ValueError("No valid predictions were generated during backtesting.")

# Instantiate and train the model
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# Run your backtest
predictions = backtest(sp500, model, new_predictors)

# Evaluation
print("Prediction distribution:")
print(predictions['Predictions'].value_counts())

print("Precision Score:")
print(precision_score(predictions["Target"], predictions["Predictions"]))

# %%
latest_data = sp500.iloc[-1:].copy()

# %%
prediction = model.predict(latest_data[new_predictors])[0]
print("Predicted Movement for April 17, 2025:", "Up" if prediction == 1 else "Down")
# Out:
# Predicted Movement for April 17, 2025: Up

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier(n_estimators=200, learning_rate=0.05, max_depth=5, use_label_encoder=False, eval_metric='logloss', random_state=1)

# %%
def predict(train, test, predictors, model, threshold=0.6):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:, 1]
    preds = (preds >= threshold).astype(int)
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250, threshold=0.6):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i + step)].copy()

        predictions = predict(train, test, predictors, model, threshold)

        if predictions is not None and not predictions.empty:
            all_predictions.append(predictions)
        else:
            print(f" No predictions returned for range {i}-{i + step}")

    if all_predictions:
        return pd.concat(all_predictions)
    else:
        raise ValueError("No valid predictions were generated during backtesting.")

# %%
model = XGBClassifier(n_estimators=200, learning_rate=0.05, max_depth=5,
                      use_label_encoder=False, eval_metric='logloss', random_state=1)

# %%
predictions = backtest(sp500, model, new_predictors)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:16:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:16:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:16:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:16:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:16:38] WARNING: /workspace/src/learner.cc:740:
# ...

# %%
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 0    4182
# 1    1206
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5671641791044776

# %%
#SVM
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
def predict(train, test, predictors, model):
    scaler = StandardScaler()

    # Fit scaler on training data and transform both train and test
    train_scaled = scaler.fit_transform(train[predictors])
    test_scaled = scaler.transform(test[predictors])

    model.fit(train_scaled, train["Target"])
    preds = model.predict(test_scaled)

    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:i + step].copy()
        predictions = predict(train, test, predictors, model)

        if predictions is not None and not predictions.empty:
            all_predictions.append(predictions)

    if all_predictions:
        return pd.concat(all_predictions)
    else:
        raise ValueError("No valid predictions were generated during backtesting.")

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', probability=False)

# %%
predictions = backtest(sp500, svm_model, new_predictors)

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5522084266232444

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from prophet import Prophet
import matplotlib.pyplot as plt

# Step 1: Load the S&P 500 data
sp500 = yf.Ticker("^GSPC").history(period="max")

# Step 2: Prepare the DataFrame for Prophet
df = sp500.reset_index()[["Date", "Close"]].copy()
df.rename(columns={"Date": "ds", "Close": "y"}, inplace=True)

# Step 3: Remove timezone info
df["ds"] = df["ds"].dt.tz_localize(None)

# Step 4: Apply log transformation to stabilize variance
df["y"] = np.log(df["y"])

# Step 5: Initialize and fit the Prophet model
model = Prophet(daily_seasonality=True)
model.fit(df)

# Step 6: Create future dataframe for next 365 days
future = model.make_future_dataframe(periods=365)

# Step 7: Predict future values
forecast = model.predict(future)

# Step 8: Exponentiate the predicted values to return to original scale
forecast["yhat"] = np.exp(forecast["yhat"])
forecast["yhat_lower"] = np.exp(forecast["yhat_lower"])
forecast["yhat_upper"] = np.exp(forecast["yhat_upper"])

# Step 9: Plot the forecast
fig = model.plot(forecast)
plt.title("S&P 500 Forecast (Using Prophet with Log Transformation)")
plt.xlabel("Date")
plt.ylabel("S&P 500 Close Price")
plt.show()
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4z60pdxk/xidvw5yb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4z60pdxk/xxl8xi6w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52429', 'data', 'file=/tmp/tmp4z60pdxk/xidvw5yb.json', 'init=/tmp/tmp4z60pdxk/xxl8xi6w.json', 'output', 'file=/tmp/tmp4z60pdxk/prophet_modelld9t_frd/prophet_model-20250417061825.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:18:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:19:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Create a binary target for the actual S&P 500 data
df["Target"] = (df["y"].diff().shift(-1) > 0).astype(int)  # 1 if the next day's price is higher, else 0

# %%
# For predicted values: create the same binary target
forecast["Predictions"] = (forecast["yhat"].diff().shift(-1) > 0).astype(int)

# %%
from sklearn.metrics import precision_score

# Align forecast to match original df's date range
predictions = forecast[forecast['ds'] <= df['ds'].max()].copy()
predictions = predictions.set_index('ds')

# Align original Target values
actual = df.set_index('ds')

# Ensure both series are aligned
predictions = predictions.loc[actual.index]

# Calculate precision score
precision = precision_score(actual["Target"], predictions["Predictions"])
print(f"Precision Score: {precision:.4f}")
# Out:
# Precision Score: 0.5374
